# %%
from requests import get,post
from dotenv import load_dotenv
import os
import base64
import json
import pandas as pd

load_dotenv()

client_id= os.getenv('client_id')
client_secret= os.getenv('client_secret')
redirect_url = 'http://localhost:8888/callback'


    
def get_token():
    auth_string= client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = base64.b64encode(auth_bytes).decode("utf-8")

    url= "https://accounts.spotify.com/api/token?"
    headers= {"Authorization": "Basic " + auth_base64,
              "Content-type": "application/x-www-form-urlencoded"
    }
    
    data = {"grant_type": "client_credentials"}
    result = post(url,headers=headers,data=data)
    json_result=json.loads(result.content)
    token= json_result["access_token"]
    return token


def get_auth_header(token):
    return {"Authorization": "Bearer " + token}


user_id='7asAr33Uw7KASjyl0RJ4Eb'

def playlist(token,user_id):
    query_url=f"https://api.spotify.com/v1/users/"+user_id+"/playlists"
    headers= get_auth_header(token)
    result= get(query_url,headers=headers)
    json_result= json.loads(result.content)
    print(json_result)



def myplaylist(token):
    myurl="https://api.spotify.com/v1/users/fnnlbzrvjex6r6tgmdx6cr4xq/playlists?limit=20"
    headers= get_auth_header(token)
    myresult= get(myurl,headers=headers)
    result=myresult.json()
    return result
    # json_results= json.loads(myresult.content)
    # print (json_results)

token= get_token()

test=myplaylist(token)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 57
#      53     return result
#      54     # json_results= json.loads(myresult.content)
#      55     # print (json_results)
# ---> 57 token= get_token()
#      59 test=myplaylist(token)
#
# Cell In[66], line 27, in get_token()
#      22 headers= {"Authorization": "Basic " + auth_base64,
#      23           "Content-type": "application/x-www-form-urlencoded"
#      24 }
#      26 data = {"grant_type": "client_credentials"}
# ---> 27 result = post(url,headers=headers,data=data,scope='playlist-read-private')
#      28 json_result=json.loads(result.content)
#      29 token= json_result["access_token"]
#
# File c:\Users\iguim\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\iguim\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# TypeError: Session.request() got an unexpected keyword argument 'scope'

# %%
a=[]
for i in test['items']:
    a.append(i)

# %%
test = pd.DataFrame(a)
test
# Out:
#    collaborative description  \
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/playlist...
# 1  {'spotify': 'https://open.spotify.com/playlist...
# 2  {'spotify': 'https://open.spotify.com/playlist...
# 3  {'spotify': 'https://open.spotify.com/playlist...
# 4  {'spotify': 'https://open.spotify.com/playlist...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/playlists/5hZLyO2s7...  5hZLyO2s7SAtQ3Urq30txx
# 1  https://api.spotify.com/v1/playlists/1miR2KQuJ...  1miR2KQuJmqTOQr4Ab3poQ
# 2  https://api.spotify.com/v1/playlists/7K5S3H7yp...  7K5S3H7ypZkXTpfm6FWsSN
# 3  https://api.spotify.com/v1/playlists/6Sr074yl9...  6Sr074yl9GohaXQy0yrCFK
# 4  https://api.spotify.com/v1/playlists/6cpeJLwDo...  6cpeJLwDojo0olf0kWaXC2
#
#                                               images              name  \
# 0  [{'height': 640, 'url': 'https://mosaic.scdn.c...      Não, Não Vou
# 1  [{'height': 640, 'url': 'https://mosaic.scdn.c...        Chop Suey!
# 2  [{'height': 640, 'url': 'https://mosaic.scdn.c...  Trap and Hip hop
# 3  [{'height': 640, 'url': 'https://mosaic.scdn.c...               Rap
# 4  [{'height': 640, 'url': 'https://mosaic.scdn.c...             Sitio
#
#                                                owner primary_color  public  \
# 0  {'display_name': 'igor', 'external_urls': {'sp...          None    True
# 1  {'display_name': 'igor', 'external_urls': {'sp...          None    True
# 2  {'display_name': 'igor', 'external_urls': {'sp...          None    True
# 3  {'display_name': 'igor', 'external_urls': {'sp...          None    True
# 4  {'display_name': 'igor', 'external_urls': {'sp...          None    True
#
#                                          snapshot_id  \
# 0  NDEsMjE5NThlNDQ5ZTczNTE1NTMyY2NjZWMzNDFiZTI4YW...
# 1  NTMsNGYzOTM5YzUzYTJkNDI4OGQxYjgxYzE0N2UyODFhZm...
# 2  MTA2LDdhNTRjZDU1OTcwOTRhMGFkYzU0NGI2MmVjYjc0Mj...
# 3  NzUsY2M3OTkyZDg5NzIwYjRmZjVlZWZiNTUzMjBkOGFlYW...
# 4  Mjg2LGJmMWRlZDM5OWZkMzc2M2Y0MjZhZDdlZmZhOGY4Yj...
#
#                                               tracks      type  \
# 0  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 1  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 2  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 3  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 4  {'href': 'https://api.spotify.com/v1/playlists...  playlist
#
#                                        uri
# 0  spotify:playlist:5hZLyO2s7SAtQ3Urq30txx
# 1  spotify:playlist:1miR2KQuJmqTOQr4Ab3poQ
# 2  spotify:playlist:7K5S3H7ypZkXTpfm6FWsSN
# 3  spotify:playlist:6Sr074yl9GohaXQy0yrCFK
# 4  spotify:playlist:6cpeJLwDojo0olf0kWaXC2
